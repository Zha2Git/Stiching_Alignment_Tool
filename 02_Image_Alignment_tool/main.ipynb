# %% [markdown]
# ## Notebook to run the core function in Alignment tool

# %%
"# Run main.py core functionality directly in the Notebook
No command line needed; set parameters and call the main processing function.

Parameters:
- `source`: Input folder path containing raw images (e.g., TIF files).
- `destination`: Output folder path where processed images are saved.
- `yes`: Execute without interaction (True for automatic run).
- `reference`: Reference channel name used for registration, typically "DAPI".
- `resolution`: Resolution of the raw images (microns per pixel).
- `disable_reassemble`: Skip reassembling CZI files (True to skip).
- `disable_registration`: Skip image registration (True to skip).
- `downscale`: Downsample large images (True to downsample).
- `factor`: Downsampling ratio, only effective when `downscale=True`.
- `nofinalimage`: Do not generate the final image combining all channels (default False, generate final image).
- `background`: Background subtraction parameter, usually 'False' or a specified background filename.
- `backgroundMult`: Background intensity multiplier.
- `fullname`: Whether output image metadata contains full channel names (True to include).
- `pyramidal`: Additionally save pyramid multi-resolution OME-TIFF (True to save).
- `output`: Output file type ('tif').
"""

# Save to a Markdown file and also show it
with open("README_en.md", "w", encoding="utf-8") as f:
    f.write(english_md)

try:
    display(Markdown(english_md))
except Exception:
    print(english_md)
# Out:
#   Cell In[3], line 1
#     "# Run main.py core functionality directly in the Notebook
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
import types
from image_registration.image_processing import run
import sys
#add HiFi Alignmenttool module to path
#sys.path.append("C:\\Users\\yangz\\Documents\\HiFiAlignmentTool\\")

# %%
import os
# Set the Argument argparse.Namespace
args = types.SimpleNamespace(
    source=r".\source",
    destination=r".\source",
    yes=True,
    reference="DAPI",
    resolution=0.325,
    disable_reassemble=True,
    disable_registration=False,
    downscale=True,
    factor=0.75,
    nofinalimage=True,
    background='False',
    backgroundMult=1,
    fullname=True,
    pyramidal=True,
    output='tif'
)

# Ensure the structure of args matches the expected structure of the run function
if hasattr(run, '__annotations__') and 'args' in run.__annotations__:
    expected_type = run.__annotations__['args']
    if not isinstance(args, expected_type):
        raise TypeError(f"Expected args of type {expected_type}, but got {type(args)}")
    
# get list of files in source directory
filelist = os.listdir(args.source)
print("Files in source directory:", filelist)
# Out:
# Files in source directory: ['Tissue_Panel1_Combined.ome.tif', 'Tissue_Panel2_Combined.ome.tif']

# %%
# Run the image registration process
run(args)
# Out:
# ------- No Reassembling done -------
# Found the following image files in .\source:
#
# Tissue_Panel1_Combined.ome.tif
# Tissue_Panel2_Combined.ome.tif
#
# ----- Extracting image dimensions and putting them in image_shape.txt -----
# ------- Verifying that CSV file matches images -------
# Reference channel is present in all images, continue program.
# ------- CSV file matches images and all images have the reference channel -------
# Reference channel used is: DAPI
# Reference image is from: Tissue_Panel1_Combined.ome.tif
# Loaded tif_ref 166.179984 MB
# Extracted chan_ref 20.772608 MB
# Getting max dimensions with:  ['.\\source\\image_shape.txt']
# ['8,2792,3720', '8,2792,3720', '']
# (i_max, j_max) ---------------  2792 3720
# ----- Images will be downscaled 75.0 %  resolution------
# -------------- 1 pixel represents 0.433 um --------------
# chan_ref rescaled 11.684648 MB
# --- Aligning tif: Tissue_Panel1_Combined.ome.tif
# Shape of image is:  (8, 2792, 3720) size 166.179984 MB
# ------- Reference Channel idx in the image: 1
# Down scaled the image to (2094, 2790) 11.684648 MB
# Getting Transform matrix
# Registration matrix acquired and now transforming the channels
# info -- channel 0 aligned
# info -- channel 1 aligned
# info -- channel 2 aligned
# info -- channel 3 aligned
# info -- channel 4 aligned
# info -- channel 5 aligned
# info -- channel 6 aligned
# info -- channel 7 aligned
# Transformed channels done, image is of size (8, 2094, 2790) 93.476304 MB
# ------- The markers of the image are:  ['DAPI1|DAPI|Tissue_Panel1_Combined', 'aSMA|Opal 480|Tissue_Panel1_Combined', 'CD3|Opal 520|Tissue_Panel1_Combined', 'CD68|Opal 570|Tissue_Panel1_Combined', 'gamma-H2AX|Opal 620|Tissue_Panel1_Combined', 'CC3|Opal 690|Tissue_Panel1_Combined', 'CD4|Opal 780|Tissue_Panel1_Combined', 'AF_P1|Autofluorescence|Tissue_Panel1_Combined']
# Saving aligned image
# ------------- Registration Duration of Tissue_Panel1_Combined : 0:00:13.119903
#
# --- Aligning tif: Tissue_Panel2_Combined.ome.tif
# Shape of image is:  (8, 2792, 3720) size 166.179984 MB
# ------- Reference Channel idx in the image: 1
# Down scaled the image to (2094, 2790) 11.684648 MB
# Getting Transform matrix
# Registration matrix acquired and now transforming the channels
# info -- channel 0 aligned
# info -- channel 1 aligned
# info -- channel 2 aligned
# info -- channel 3 aligned
# info -- channel 4 aligned
# info -- channel 5 aligned
# info -- channel 6 aligned
# info -- channel 7 aligned
# Transformed channels done, image is of size (8, 2094, 2790) 93.476304 MB
# ------- The markers of the image are:  ['DAPI2|DAPI|Tissue_Panel2_Combined', 'Granzyme B|Opal 480|Tissue_Panel2_Combined', 'CD8|Opal 520|Tissue_Panel2_Combined', 'panCK|Opal 570|Tissue_Panel2_Combined', 'Ki67|Opal 620|Tissue_Panel2_Combined', 'PD-L1|Opal 690|Tissue_Panel2_Combined', '-|Opal 780|Tissue_Panel2_Combined', 'AF_P2|Autofluorescence|Tissue_Panel2_Combined']
# Saving aligned image
# ------------- Registration Duration of Tissue_Panel2_Combined : 0:00:15.090774
#
# DONE! All images are registered
# --- Total Registration Duration: 0:00:28.635032
#
# Found the following image files in ./aligned:
#
# Tissue_Panel1_Combined_al.ome.tif
# Tissue_Panel2_Combined_al.ome.tif
#
# -------------- Final image --------------
# Final image size will have: 16 channels
# -------------- Full marker names in the final image metadata
# Adding first image: Tissue_Panel1_Combined_al.ome.tif  ------  (8, 2094, 2790)
# --- Adding: Tissue_Panel2_Combined_al.ome.tif
# Image size:  186.952464 MB
# Final image size:  (16, 2094, 2790) 186.952464 MB
# Final image saved!
# --------- Final_image Duration: 0:00:00.409880
#
# -------------- Pyramidal Compressed Final image --------------
# Initial image dimension (16, 2094, 2790)
# Level 1 image dimension (16, 1047, 1395)
# Level 2 image dimension (16, 524, 698)
# Level 3 image dimension (16, 262, 349)
# DONE, compressed pyramidal image saved!
# --------- Pyramidal_final_image Duration: 0:00:06.261653
#
# --- Total Duration: 0:00:35.556979
